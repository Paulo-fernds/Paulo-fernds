# %% [markdown]
# <a href="https://colab.research.google.com/github/Paulo-fernds/Paulo-fernds/blob/main/roboflow_yolov8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 744.8/744.8 kB 9.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 44.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 54.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 55.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 11.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.0 MB/s eta 0:00:00
# ...

# %%
from roboflow import Roboflow

rf = Roboflow(api_key='yWJAirSWZPyZn9Kjrt9S')
project = rf.workspace().project('tomates-4blsk')
dataset = project.version(1).download('yolov8')
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.1.41, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to Tomates-1 in yolov8:: 100%|██████████| 258/258 [00:00<00:00, 5956.77it/s]

# %%
from ultralytics import YOLO

# %%
# !yolo task=detect \
mode=train \
model=yolov8s \
data=/content/Tomates-1/data.yaml \
epochs=100 \
imgsz=640
# Out:
# Ultralytics YOLOv8.1.41 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="rcinBIxI6md6km4ZmyR0")
project = rf.workspace("projects-h4wwz").project("aaaaaa-y4lbk")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.1.41, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to aaaaaa-1 in yolov8:: 100%|██████████| 950/950 [00:00<00:00, 1888.95it/s]

# %%
# !yolo task=detect \
mode=train \
model=yolov8s \
data={dataset.location}/data.yaml \
epochs=100 \
imgsz=640
# Out:
# Ultralytics YOLOv8.1.41 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect \
mode=predict \
model=/content/runs/detect/train2/weights/best.pt \
conf=0.50 \
source=/content/aaaaaa-1/test/images
# Out:
# Ultralytics YOLOv8.1.41 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11127132 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/47 /content/aaaaaa-1/test/images/00004_jpg.rf.3a8adfa593a130f123402f308e43167c.jpg: 640x640 1 Colete, 16.3ms
# image 2/47 /content/aaaaaa-1/test/images/00121_jpg.rf.0875c1df0b0c7165a2b8a82a3fb1a47e.jpg: 640x640 1 Colete, 16.4ms
# image 3/47 /content/aaaaaa-1/test/images/00274_jpg.rf.1439c36b65507416a0667c56fc00adfc.jpg: 640x640 1 Colete, 16.3ms
# image 4/47 /content/aaaaaa-1/test/images/20220721_162229_jpg.rf.81d5794cd904ad3d2f935d4bc4071117.jpg: 640x640 (no detections), 16.3ms
# image 5/47 /content/aaaaaa-1/test/images/51_JPG_jpg.rf.bbc861b4a9171b6657c2814ce4900383.jpg: 640x640 1 capacete, 1 mascara, 1 oculos, 16.2ms
# image 6/47 /content/aaaaaa-1/test/images/59_JPG_jpg.rf.be7479bf1e62848ce8b7113b5ddd9884.jpg: 640x640 1 capacete, 1 mascara, 2 oculoss, 16.2ms
# ...

# %%
# !yolo task=detect \
mode=predict \
model=/content/runs/detect/train4/weights/best.pt \
conf=0.50 \
source=/content/Tomates-1/test/images
# Out:
# Ultralytics YOLOv8.1.41 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126745 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/17 /content/Tomates-1/test/images/-1-_fake_A_png_jpg.rf.7179ff1263755509d6c79c48afff8ef3.jpg: 640x640 4 podres, 3 verdes, 16.0ms
# image 2/17 /content/Tomates-1/test/images/-10-_fake_A_png_jpg.rf.b6b8c06322f9be80e45dca9c7bdd25e0.jpg: 640x640 2 podres, 1 verde, 16.1ms
# image 3/17 /content/Tomates-1/test/images/-3-_fake_A_png_jpg.rf.b399b79db9b122a589ee0534cb71f4e5.jpg: 640x640 9 podres, 15.9ms
# image 4/17 /content/Tomates-1/test/images/-4-_fake_A_png_jpg.rf.aba63008206549902e3cee38441cce8b.jpg: 640x640 4 podres, 15.9ms
# image 5/17 /content/Tomates-1/test/images/-4-_png_fake_A_png_jpg.rf.a73596f748ce22f9d9c3afb60c21cdd3.jpg: 640x640 5 maduros, 5 podres, 3 verdes, 15.9ms
# ...

# %%
# !zip -r /content/predictpaulo /content/runs/detect/predict3
# Out:
#   adding: content/runs/detect/predict3/ (stored 0%)
#   adding: content/runs/detect/predict3/zaq_fake_A_png_jpg.rf.4db8ee42299a5c65b34039c02985f05f.jpg (deflated 3%)
#   adding: content/runs/detect/predict3/zcvbn_fake_A_png_jpg.rf.c9fa96592697d842d19f1c4bac60b997.jpg (deflated 4%)
#   adding: content/runs/detect/predict3/-5-_fake_A_png_jpg.rf.562724ef4b76a6f2c46ceee35d6cfda9.jpg (deflated 2%)
#   adding: content/runs/detect/predict3/z5601_fake_A_png_jpg.rf.66fd819f42dc79ea9d200ef620d3e06f.jpg (deflated 4%)
#   adding: content/runs/detect/predict3/ycgvh_fake_A_png_jpg.rf.c1535c73df676b5634f4c423edc5c4db.jpg (deflated 3%)
#   adding: content/runs/detect/predict3/z48651-z_fake_A_png_jpg.rf.54e1d4629100a83440970a37968e1871.jpg (deflated 3%)
#   adding: content/runs/detect/predict3/-1-_fake_A_png_jpg.rf.7179ff1263755509d6c79c48afff8ef3.jpg (deflated 3%)
#   adding: content/runs/detect/predict3/-10-_fake_A_png_jpg.rf.b6b8c06322f9be80e45dca9c7bdd25e0.jpg (deflated 4%)
# ...
